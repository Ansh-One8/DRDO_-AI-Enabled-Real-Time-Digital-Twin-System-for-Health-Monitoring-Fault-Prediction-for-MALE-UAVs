# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('uav_training_data.csv')

# Display the first 5 rows to verify it loaded correctly
display(df.head())

# Show a summary of the columns, data types, and non-null counts
df.info()
# Out:
#    python -m ipykernel install --user --name=uav_env --display-name "Python (UAV Digital Twin)"flight_id  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#     t_s phase  throttle_pct  altitude_m  ambient_c       rpm  map_inHg  \
# 0   0.0  taxi          15.3         0.0       40.0  2513.196    14.313
# 1  10.0  taxi          15.9         0.0       40.0  2544.307    14.771
# 2  20.0  taxi          14.8         0.0       40.0  2485.028    14.304
# 3  30.0  taxi          17.1         0.0       40.0  2626.515    14.742
# 4  40.0  taxi          15.7         0.0       40.0  2523.532    14.702
#
#       cht      egt  oil_pressure  oil_temp  fuel_flow  vibration  \
# 0  46.132  407.841         3.697    41.682      4.686      0.651
# ...

# %%
df.head()
# Out:
#    python -m ipykernel install --user --name=uav_env --display-name "Python (UAV Digital Twin)"flight_id  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#     t_s phase  throttle_pct  altitude_m  ambient_c       rpm  map_inHg  \
# 0   0.0  taxi          15.3         0.0       40.0  2513.196    14.313
# 1  10.0  taxi          15.9         0.0       40.0  2544.307    14.771
# 2  20.0  taxi          14.8         0.0       40.0  2485.028    14.304
# 3  30.0  taxi          17.1         0.0       40.0  2626.515    14.742
# 4  40.0  taxi          15.7         0.0       40.0  2523.532    14.702
#
#       cht      egt  oil_pressure  oil_temp  fuel_flow  vibration  \
# 0  46.132  407.841         3.697    41.682      4.686      0.651
# ...
